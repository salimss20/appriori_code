# %%
import pandas as pd
import numpy as np
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

   ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)    #Apply one-hot-encoding on our dataset
df=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %%
cleanup={"Pants":{"True":1, "False": 0}} 
cleanup={"Skirt":{"True":1, "False": 0}} 
df[["Pants", "Skirt"]].groupby(["Pants"], as_index=True).mean()
# Out:
#        Skirt
# Pants
# False   0.00
# True    0.75

# %%
df[["Pants", "Skirt"]].groupby(["Skirt"], as_index=True).mean()
# Out:
#        Pants
# Skirt
# False    0.5
# True     1.0

# %%
x=df["Pants"].value_counts()
print(x)
# Out:
# True     4
# False    1
# Name: Pants, dtype: int64
# 2

# %%
from mlxtend.frequent_patterns import apriori
apriori(df, min_support=0.6)
# Out:
#    support itemsets
# 0      0.6      (2)
# 1      0.8      (5)
# 2      0.8      (7)
# 3      0.6      (9)
# 4      0.6   (5, 7)
# 5      0.6   (9, 5)

# %%
from mlxtend.frequent_patterns import apriori
apriori(df, min_support=0.6)
# Out:
#    support itemsets
# 0      0.6      (2)
# 1      0.8      (5)
# 2      0.8      (7)
# 3      0.6      (9)
# 4      0.6   (5, 7)
# 5      0.6   (9, 5)

# %%
frequent_itemsets=apriori(df, min_support=0.6, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Pants, Scarf)
# 5      0.6  (Pants, Skirt)

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7) # associate itemsets with confidence over 70%.
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 1     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 2     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 3     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  0.9375     -0.04         0.8
# 1        0.75  0.9375     -0.04         0.8
# 2        0.75  1.2500      0.12         1.6
# 3        1.00  1.2500      0.12         inf

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="lift",min_threshold=1)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 1     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0        0.75  1.25      0.12         1.6
# 1        1.00  1.25      0.12         inf

# %% [markdown]
# ## dataset NUM 2

# %%
df1=pd.read_csv("Market_Basket_Optimisation.csv",sep=',')
df1
# Out:
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress       5 non-null      bool
#  1   Earrings    5 non-null      bool
#  2   Hat         5 non-null      bool
#  3   Heels       5 non-null      bool
#  4   Necklace    5 non-null      bool
#  5   Pants       5 non-null      bool
#  6   Sandals     5 non-null      bool
#  7   Scarf       5 non-null      bool
#  8   Shirt       5 non-null      bool
#  9   Skirt       5 non-null      bool
#  10  Sneakers    5 non-null      bool
#  11  Sunglasses  5 non-null      bool
# dtypes: bool(12)
# memory usage: 188.0 bytes

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(df1).transform(df1)    #Apply one-hot-encoding on our dataset
df2=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df2
# Out:
#                  a      b      c      d      e      f      g      h      i  \
# 0     False  False  False  False  False  False  False  False   True   True
# 1     False   True  False  False   True  False  False  False  False  False
# 2     False   True  False   True   True  False  False  False  False  False
# 3      True   True   True  False  False   True  False   True  False   True
# 4      True   True  False  False  False   True  False   True  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7495  False  False  False  False  False  False  False  False  False  False
# 7496  False  False  False  False  False  False  False  False  False  False
# 7497  False  False  False  False  False  False  False  False  False  False
# 7498  False  False  False  False  False  False  False  False  False  False
# 7499  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
from mlxtend.frequent_patterns import apriori
apriori(df2, min_support=0.9)
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
frequent_itemsets=apriori(df2, min_support=0.6, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7) # associate itemsets with confidence over 70%.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14112/3142850621.py in <module>
#       1 from mlxtend.frequent_patterns import association_rules
# ----> 2 association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7) # associate itemsets with confidence over 70%.
#
# ~\anaconda3\lib\site-packages\mlxtend\frequent_patterns\association_rules.py in association_rules(df, metric, min_threshold, support_only)
#      78     """
#      79     if not df.shape[0]:
# ---> 80         raise ValueError('The input DataFrame `df` containing '
#      81                          'the frequent itemsets is empty.')
#      82
#
# ValueError: The input DataFrame `df` containing the frequent itemsets is empty.
